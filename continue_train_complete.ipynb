# %%
from google.colab import drive 
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.9.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.9.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-08-26 09:02:23--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90040905 (86M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.9 100%[===================>]  85.87M   130MB/s    in 0.7s
#
# 2021-08-26 09:02:24 (130 MB/s) - ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh.1’ saved [90040905/90040905]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py37h261ae71_2
# ...

# %%
# # requirements.txt 생성
p = """
gensim==3.8.1
pyLDAvis==2.1.2
spacy==2.2.3
scikit-learn==0.23.1
seaborn==0.11.0
squarify==0.4.3
ipykernel
nltk
pandas
scipy
"""

c = """text_file = open("requirements.txt", "w+");text_file.write(p);text_file.close()""" 

exec(c)

# %%
# !conda install --channel conda-forge --file requirements.txt --yes
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - gensim==3.8.1
#     - ipykernel
#     - nltk
#     - pandas
#     - pyldavis==2.1.2
#     - scikit-learn==0.23.1
#     - scipy
#     - seaborn==0.11.0
#     - spacy==2.2.3
#     - squarify==0.4.3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     argcomplete-1.12.3         |     pyhd8ed1ab_2          34 KB  conda-forge
#     attrs-21.2.0               |     pyhd8ed1ab_0          44 KB  conda-forge
#     backcall-0.2.0             |     pyh9f0ad1d_0          13 KB  conda-forge
# ...

# %%
# !conda create -n tryon python=3.6
# Out:
# WARNING: A conda environment already exists at '/usr/local/envs/tryon'
# Remove existing environment (y/[n])? y
#
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/tryon
#
#   added / updated specs:
#     - python=3.6
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2021.7.5-h06a4308_1
#   certifi            pkgs/main/linux-64::certifi-2021.5.30-py36h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
# ...

# %%
# !conda activate tryon && conda env list
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !conda install pytorch=1.1.0 torchvision=0.3.0 cudatoolkit=9.0 -c pytorch
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=9.0
#     - pytorch=1.1.0
#     - torchvision=0.3.0
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2021.5.3~ --> pkgs/main::ca-certificates-2021.7.5-h06a4308_1
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1k-h27cfd23_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2021.5.30-py37h8~ --> pkgs/main::certifi-2021.5.30-py37h06a4308_0
#
#
# Proceed ([y]/n)? y
#
# done
# done
# done

# %%
# !conda install cupy or pip install cupy==6.0.0

# %%
# !nvidia-smi
# Out:
# Thu Aug 26 09:08:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    28W / 149W |      0MiB / 11441MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install cupy-cuda101==6.1.0

# %%
# !pip install opencv-python

# %%
# # requirements2.txt 생성
p = """
torch
Pillow
torchvision
tensorboardX
opencv-python
cupy-cuda101==6.1.0
"""

r = """text_file = open("requirements2.txt", "w+");text_file.write(p);text_file.close()""" 

exec(r)

# %%
# !pip install -r requirements2.txt

# %%
# !git clone https://github.com/geyuying/PF-AFN.git

# %%
# %cd ./gdrive/MyDrive/PF-AFN/PF-AFN/PF-AFN_train
# Out:
# /content/gdrive/MyDrive/PF-AFN/PF-AFN/PF-AFN_train

# %%
! chmod 770 ./scripts/train_PBAFN_stage1.sh
! chmod 770 ./scripts/train_PBAFN_e2e.sh
! chmod 770 ./scripts/train_PFAFN_stage1.sh
! chmod 770 ./scripts/train_PFAFN_e2e.sh

# %%
! ./scripts/train_PBAFN_stage1.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: None
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: None
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 100
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_stage1
# ndf: 64
# netG: global
# ngf: 64
# niter: 50
# niter_decay: 50
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# ...

# %%
! chmod 770 ./scripts/copy_of_train_PBAFN_stage1.sh

# %%
! ./scripts/copy_of_train_PBAFN_stage1.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: None
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: None
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 100
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_stage1
# ndf: 64
# netG: global
# ngf: 64
# niter: 50
# niter_decay: 50
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# ...

# %%
! ./scripts/copy_of_train_PBAFN_stage1.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: None
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: checkpoints/PBAFN_stage1
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 50
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_stage1
# ndf: 64
# netG: global
# ngf: 64
# niter: 10
# niter_decay: 10
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# ...

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 --master_port=7129 copy_of_train_PBAFN_stage1.py --name PBAFN_stage1   \
--continue_train --resize_or_crop None --verbose --tf_log --batchSize 4 --num_gpus 1 --label_nc 14 --launcher pytorch   \
--PFAFN_warp_checkpoint checkpoints/PBAFN_stage1 --save_epoch_freq 5 --niter 10 --niter_decay 10 --display_freq 50
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: None
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: checkpoints/PBAFN_stage1
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 50
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_stage1
# ndf: 64
# netG: global
# ngf: 64
# niter: 10
# niter_decay: 10
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# ...

# %%
import os

checkpoints_list = []
checkpoints_dir = './checkpoints/'
name = 'PBAFN_stage1'
checkpoint_path = os.path.join(checkpoints_dir, name)
cp_dirs = os.listdir(checkpoint_path)
for cp in cp_dirs:
    checkpoints_list.append(cp)
checkpoints_list.sort()
latest_checkpoint = checkpoints_list[-2]
print(latest_checkpoint)
print(latest_checkpoint.split('_')[-1][:3])
# Out:
# PBAFN_warp_epoch_101.pth
# 101

# %%
! ./scripts/copy_of_train_PBAFN_stage1.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: None
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: checkpoints/PBAFN_stage1
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 50
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_stage1
# ndf: 64
# netG: global
# ngf: 64
# niter: 10
# niter_decay: 10
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# pool_size: 0
# ...

# %%
! ./scripts/copy_of_train_PBAFN_stage1.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: None
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: checkpoints/PBAFN_stage1
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 50
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_stage1
# ndf: 64
# netG: global
# ngf: 64
# niter: 10
# niter_decay: 50
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# pool_size: 0
# print_freq: 100
# ...

# %%
! ./scripts/train_PBAFN_e2e.sh
# Out:
# ------------ Options -------------
# PBAFN_gen_checkpoint: None
# PBAFN_warp_checkpoint: checkpoints/PBAFN_stage1/PBAFN_warp_epoch_81.pth
# PFAFN_gen_checkpoint: None
# PFAFN_warp_checkpoint: None
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: dataset/VITON_traindata/
# debug: False
# display_freq: 100
# display_winsize: 512
# fineSize: 512
# gpu_ids: [0]
# input_nc: 3
# isTrain: True
# label_nc: 14
# lambda_feat: 10.0
# launcher: pytorch
# loadSize: 512
# load_pretrain:
# local_rank: 0
# lr: 5e-05
# max_dataset_size: inf
# nThreads: 1
# n_blocks_global: 4
# n_blocks_local: 3
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: PBAFN_e2e
# ndf: 64
# netG: global
# ngf: 64
# niter: 50
# niter_decay: 50
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# num_gpus: 1
# output_nc: 3
# phase: train
# ...
